# %%
from keras.preprocessing import image
# dimensions of our images
img_width, img_height = 320, 240
img = image.load_img('COVID-00001.jpg', target_size=(img_width, img_height))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=240x320 at 0x27CD170A2E8>

# %%
img_array = x = image.img_to_array(img)

# %%
img_array
# Out:
# array([[[ 32.,  32.,  32.],
#         [ 15.,  15.,  15.],
#         [ 34.,  34.,  34.],
#         ...,
#         [ 14.,  14.,  14.],
#         [ 19.,  19.,  19.],
#         [  2.,   2.,   2.]],
#
#        [[ 32.,  32.,  32.],
#         [ 31.,  31.,  31.],
#         [ 19.,  19.,  19.],
#         ...,
#         [ 16.,  16.,  16.],
#         [  0.,   0.,   0.],
#         [ 21.,  21.,  21.]],
#
#        [[ 32.,  32.,  32.],
#         [ 16.,  16.,  16.],
#         [ 16.,  16.,  16.],
#         ...,
#         [  4.,   4.,   4.],
#         [  0.,   0.,   0.],
#         [  0.,   0.,   0.]],
#
#        ...,
#
#        [[152., 152., 152.],
#         [170., 170., 170.],
#         [152., 152., 152.],
#         ...,
#         [206., 206., 206.],
#         [187., 187., 187.],
#         [184., 184., 184.]],
#
#        [[151., 151., 151.],
#         [153., 153., 153.],
#         [154., 154., 154.],
#         ...,
#         [204., 204., 204.],
#         [186., 186., 186.],
# ...
